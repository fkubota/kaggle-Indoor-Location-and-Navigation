# %% [markdown]
# # Overview
# - nb002を1つのサイトだけで学習してみる

# %%
import subprocess
cmd = "git rev-parse --short HEAD"
hash = subprocess.check_output(cmd.split()).strip().decode('utf-8')
print(hash)
# Out:
# 1c30b36

# %% [markdown]
# # Const

# %%
NB = '025'
SITE = '5c3c44b80379370013e0fd2b'
DIR_TRAIN = './../data_ignore/input/train/'
DIR_TEST = './../data_ignore/input/test/'
DIR_WIFI = './../data_ignore/input/wifi/'
PATH_SUB = './../data_ignore/input/sample_submission.csv'
PATH_99_SUB = './../data/input/floor_99per_acc_sub.csv'
DIR_SAVE_IGNORE = f'./../data_ignore/nb/{NB}/'
DIR_SAVE = f'./../data/nb/{NB}/'

# %%
config_str = '''
globals:
    seed: 5713
    device: cuda
    n_label: 24
    n_splits: 5
    random_sate: 45
    lr: 0.005
    patience: 10
    epoch: 100
    batch_size: 512
    skip_evaluate_num: 5
    num_feats: 20
    t_mux: 10
'''

# %% [markdown]
# # Import everything I need:)

# %%
import os
import yaml
import types
import random
import pickle
import builtins
import numpy as np
import pandas as pd
from icecream import ic
# from tqdm import tqdm
from fastprogress import progress_bar, master_bar
from glob import glob
from loguru import logger
from collections import OrderedDict

# sklearn
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import KFold

# pytorch
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# # Function

# %%
def imports():
    for name, val in globals().items():
        # module imports
        if isinstance(val, types.ModuleType):
            yield name, val

            # functions / callables
        if hasattr(val, '__call__'):
            yield name, val


def noglobal(f):
    '''
    ref: https://gist.github.com/raven38/4e4c3c7a179283c441f575d6e375510c
    '''
    return types.FunctionType(f.__code__,
                              dict(imports()),
                              f.__name__,
                              f.__defaults__,
                              f.__closure__
                              )


def comp_metric(xhat, yhat, fhat, x, y, f):
    intermediate = np.sqrt(np.power(xhat-x, 2) + np.power(yhat-y, 2)) + 15 * np.abs(fhat-f)
    return intermediate.sum()/xhat.shape[0]

def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

# %% [markdown]
# # Preparation

# %% [markdown]
# load config

# %%
config = yaml.safe_load(config_str)
config
# Out:
# {'globals': {'seed': 5713,
#   'device': 'cuda',
#   'n_label': 24,
#   'n_splits': 5,
#   'random_sate': 45,
#   'lr': 0.005,
#   'patience': 10,
#   'epoch': 100,
#   'batch_size': 512,
#   'skip_evaluate_num': 5,
#   'num_feats': 20,
#   't_mux': 10}}

# %% [markdown]
# <br>
#
# set

# %%
seed_everything(config['globals']['seed'])

if not os.path.exists(DIR_SAVE_IGNORE):
    os.makedirs(DIR_SAVE_IGNORE)
if not os.path.exists(DIR_SAVE):
    os.makedirs(DIR_SAVE)

# %% [markdown]
# <br>
#
# load dataset

# %% [raw]
# train_files = sorted(glob(f'{DIR_WIFI}*_train.csv'))
# test_files = sorted(glob(f'{DIR_WIFI}*_test.csv'))
# sample_sub = pd.read_csv(PATH_SUB)

# %%
with open(f'{DIR_WIFI}train_all.pkl', 'rb') as f:
    df_train = pickle.load( f)
with open(f'{DIR_WIFI}test_all.pkl', 'rb') as f:
    df_test = pickle.load( f)

# %% [markdown]
# <br>
#
# site絞る

# %%
df_train = df_train[df_train.site_id == SITE]
df_test = df_test[df_test.site_id == SITE]

# %% [markdown]
# <br>
#
# preprocessing

# %%
bssid_feats = [f'bssid_{i}' for i in range(config['globals']['num_feats'])]
rssi_feats  = [f'rssi_{i}' for i in range(config['globals']['num_feats'])]

# %%
# bssidの一覧作成
# wifi_bassidにはtrainとtest両方のbssidの一覧が含まれる

wifi_bssids = []
for i in range(100):
    wifi_bssids.extend(df_train.iloc[:,i].values.tolist())
wifi_bssids = list(set(wifi_bssids))

wifi_bssids_size = len(wifi_bssids)
print(f'BSSID TYPES: {wifi_bssids_size}')

wifi_bssids_test = []
for i in range(100):
    wifi_bssids_test.extend(df_test.iloc[:,i].values.tolist())
wifi_bssids_test = list(set(wifi_bssids_test))

wifi_bssids_size = len(wifi_bssids_test)
print(f'BSSID TYPES: {wifi_bssids_size}')

wifi_bssids.extend(wifi_bssids_test)
wifi_bssids_size = len(wifi_bssids)
print(f'BSSID TYPES: {wifi_bssids_size}')
# Out:
# BSSID TYPES: 2747
# BSSID TYPES: 489
# BSSID TYPES: 3236

# %% [raw]
# # bssidの一覧作成
# # wifi_bassidにはtrainとtest両方のbssidの一覧が含まれる
#
# wifi_bssids = []
# for i in range(100):
#     wifi_bssids.extend(df_train.iloc[:, i].values.tolist())
#     wifi_bssids.extend(df_test.iloc[:, i].values.tolist())
#
# wifi_bssids = list(set(wifi_bssids))
# print(f'BSSID TYPES: {len(wifi_bssids)}')

# %%
# LabelEncoding & StandardScaler

le = LabelEncoder()
le.fit(wifi_bssids)
le_site = LabelEncoder()
le_site.fit(df_train['site_id'])

ss = StandardScaler()
ss.fit(df_train.loc[:, rssi_feats])
# Out:
# StandardScaler()

# %%
df_train.loc[:, rssi_feats] = ss.transform(df_train.loc[:, rssi_feats])
df_test.loc[:, rssi_feats] = ss.transform(df_test.loc[:, rssi_feats])
for feat in bssid_feats:
    df_train.loc[:, feat] = le.transform(df_train.loc[:, feat])
    df_test.loc[:, feat] = le.transform(df_test.loc[:, feat])
    
    df_train.loc[:, feat] = df_train.loc[:, feat] + 1
    df_test.loc[:, feat] = df_test.loc[:, feat] + 1
    
df_train.loc[:, 'site_id'] = le_site.transform(df_train.loc[:, 'site_id'])
df_test.loc[:, 'site_id'] = le_site.transform(df_test.loc[:, 'site_id'])

df_train.loc[:, rssi_feats] = ss.transform(df_train.loc[:, rssi_feats])
df_test.loc[:, rssi_feats] = ss.transform(df_test.loc[:, rssi_feats])

# %%
site_count = len(df_train['site_id'].unique())
df_train.reset_index(drop=True, inplace=True)

# %%
df_train.head()
# Out:
#    bssid_0  bssid_1  bssid_2  bssid_3  bssid_4  bssid_5  bssid_6  bssid_7  \
# 0     2231      119     1878     2689     1191     1853      903     2221
# 1      119     2231     1853     1010     1878     2627     2689      208
# 2      119     2231     1853     2627      208     1676     1191     1333
# 3     2627     1853     2231      119      960     1787     2221     1172
# 4     1853     2627     2231      119      903     2067     2400     2346
#
#    bssid_8  bssid_9  ...  rssi_95  rssi_96  rssi_97  rssi_98  rssi_99  \
# 0     1070     2627  ...      -65      -65      -65      -66      -66
# 1      998     2596  ...      -65      -65      -66      -66      -66
# 2      567     2221  ...      -65      -65      -65      -65      -65
# 3     1461      413  ...      -66      -66      -66      -66      -66
# 4     2349     2046  ...      -66      -67      -67      -67      -67
#
#            x          y  floor                      path  site_id
# 0  258.99582  107.52311     -1  5d8c805cba656a000636d4aa        0
# 1  258.99582  107.52311     -1  5d8c805cba656a000636d4aa        0
# 2  263.35950  117.29801     -1  5d8c805cba656a000636d4aa        0
# 3  263.35950  117.29801     -1  5d8c805cba656a000636d4aa        0
# 4  263.35950  117.29801     -1  5d8c805cba656a000636d4aa        0
#
# [5 rows x 205 columns]

# %% [markdown]
# # Execute

# %%
class EarlyStopping:
    """
    Early stops the training if validation loss doesn't improve after a given patience.
    based on: https://github.com/Bjarten/early-stopping-pytorch
    """
    def __init__(self, save_name, fold, patience=7, verbose=False, delta=0):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.fold = fold
        self.save_name = save_name

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            logger.info(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            logger.info(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
            
        torch.save(model.state_dict(),  f'{self.save_name}_{self.fold}.pt')
        self.val_loss_min = val_loss

# %%
class IndoorWiFiNet(nn.Module):
    def __init__(self, bssid_size, site_size, num_feats):
        super(IndoorWiFiNet, self).__init__()
        self.bssid_embedding = nn.Embedding(bssid_size, 64, max_norm=True)
        self.site_embedding = nn.Embedding(site_size, 64, max_norm=True)

        self.rssi = nn.Sequential(
            nn.BatchNorm1d(20),
            nn.Linear(20, num_feats * 64)
        )

        concat_size = 64 + (num_feats * 64) + (num_feats * 64)
        self.bn1 = nn.BatchNorm1d(concat_size)

        self.flatten = nn.Flatten()

        self.dropout1 = nn.Dropout(0.3)
        self.linear1 = nn.Linear(in_features=concat_size, out_features=256)#, bias=False)
        self.bn2 = nn.BatchNorm1d(256)

        self.linear2 = nn.Linear(in_features=256, out_features=128)#, bias=False)
        self.linear3 = nn.Linear(in_features=128, out_features=16)#, bias=False)

        self.bn3 = nn.BatchNorm1d(128)
        self.bn4 = nn.BatchNorm1d(16)


        self.xy = nn.Linear(in_features=16, out_features=2)#, bias=False)
        self.floor = nn.Linear(in_features=16, out_features=1)#, bias=False)
        

    def forward(self, bssid, rssi, site):

        site = torch.reshape(site, (-1, 1))

        bssid_out = self.bssid_embedding(bssid)
        site_out = self.site_embedding(site)

        rssi_out = self.rssi(rssi)

        bssid_out = self.flatten(bssid_out)
        site_out = self.flatten(site_out)

        x = torch.cat([bssid_out, rssi_out, site_out], dim=1)
        x = self.bn1(x)
        x = self.dropout1(x)
        x = F.relu(self.linear1(x))
        x = self.bn2(x)

        x = F.relu(self.linear2(x))
        x = self.bn3(x)

        x = F.relu(self.linear3(x))
        x = self.bn4(x)

        #x = self.lstm(x)

        xy = self.xy(x)
        floor = self.floor(x)

        return xy, floor

# %%
class IndoorWiFiDataSet(Dataset):
    def __init__(self, wifi_df, bssid_feats_, rssi_feats_, data_type='test'):
        self.wifi_df = wifi_df
        self.data_type = data_type
        self.bssids = wifi_df[bssid_feats_].to_numpy().astype(np.int)    # <----- リファクタ
        self.rssis = wifi_df[rssi_feats_].to_numpy().astype(np.float)    # <----- リファクタ
        self.site_ids = wifi_df['site_id'].to_numpy()
        if data_type in ['train', 'valid']:
            self.floors = wifi_df['floor'].to_numpy().astype(np.int)
            self.xs = wifi_df['x'].to_numpy()
            self.ys = wifi_df['y'].to_numpy()
        
    def __len__(self):
        return len(self.wifi_df)

    def __getitem__(self, idx):

        #wifi_row = self.wifi_df.iloc[idx]

        bssid = self.bssids[idx,:]
        rssi = self.rssis[idx,:]
        site_id = self.site_ids[idx]

        if self.data_type in ['test', 'valid']:
            return bssid, rssi, site_id

        elif self.data_type == 'train':
            x = self.xs[idx]
            y = self.ys[idx]
            floor = self.floors[idx]

            return bssid, rssi, site_id, x, y, floor

# %%
class IndoorLoss(nn.Module):
    def __init__(self):
        super().__init__()

        self.mse = nn.MSELoss()

    def forward(self, x, y, floor, x_pred, y_pred, floor_pred):

        x_loss = self.mse(x, x_pred)
        y_loss = self.mse(y, y_pred)
        floor_loss = self.mse(floor, floor_pred)

        return x_loss + y_loss + floor_loss

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device(config['globals']['device'])

# %%
# %%time

oof_x = np.zeros((len(df_train)))
oof_y = np.zeros((len(df_train)))
oof_floor = np.zeros((len(df_train)))
cv_scores = {}

kf = KFold(n_splits=config['globals']['n_splits'], random_state=42, shuffle=True)
for fold, (train_index, valid_index) in enumerate(kf.split(df_train)):
    print(f'\r\n====== {fold + 1} ======')
    net = IndoorWiFiNet(wifi_bssids_size, site_count, config['globals']['num_feats'])
    net = net.to(device)

    #criterion = IndoorLoss()
    criterion = nn.MSELoss()
    criterion = criterion.to(device)
    #optimizer = optim.SGD(net.parameters(), lr=Config.LR, weight_decay=0.0001, momentum=0.9)
    optimizer = torch.optim.Adam(net.parameters(), lr=config['globals']['lr'])
    
    train, valid = df_train.iloc[train_index], df_train.iloc[valid_index]

    # TODO oof用のdataloaderはいらないはず
    train_dataset = IndoorWiFiDataSet(train.reset_index(drop=True), bssid_feats, rssi_feats, data_type='train')
    valid_dataset = IndoorWiFiDataSet(valid.reset_index(drop=True), bssid_feats, rssi_feats, data_type='valid')

    trainloader = DataLoader(train_dataset, batch_size=config['globals']['batch_size'], shuffle=True, drop_last=True, num_workers=4)
    validloader = DataLoader(valid_dataset, batch_size=config['globals']['batch_size'], num_workers=4)

    early_stopping = EarlyStopping(save_name=f'{DIR_SAVE_IGNORE}checkpoint_{NB}', fold=fold+1, patience=config['globals']['patience'], verbose=True)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=config['globals']['t_mux'])


    ############# TRAIN #############
    val_losses = []
    val_metrics = []
    mb = master_bar(range(1, config['globals']['epoch']+1))
    for epoch in mb:
        mb.main_bar.comment = f'epoch = {epoch}'
        running_loss = 0.0
        #train_lwlrap = 0.0
#         n_iter = len(trainloader)
#         with tqdm(enumerate(trainloader), total=n_iter) as pbar:
        for i, (bssid, rssi, site_id, x, y, floor) in enumerate(progress_bar(trainloader, parent=mb)):
            net.train()
            # zero the parameter gradients
            optimizer.zero_grad()

            bssid, rssi, site_id, x, y, floor = bssid.to(device).long(), rssi.to(device).float(), site_id.to(device).long(), x.to(device).float(), y.to(device).float(), floor.to(device)

            xy_pred, floor_pred = net(bssid, rssi, site_id)
            xy_pred = xy_pred.transpose(0, 1).squeeze(-2).reshape(-1)
            label = torch.cat([x, y], dim=-1)
            loss = criterion(xy_pred, label)
            #loss = criterion(x, y, floor, x_pred, y_pred, floor_pred)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
#             mb.child.comment(OrderedDict(
#                 epoch="{:>10}".format(epoch), loss="{:.4f}".format(loss.item())
#             ))
            mb.child.comment = f'loss={loss.item():.4f}'
        scheduler.step()
            
        #if epoch < Config.SKIP_EVALUATE_NUM:
        #    continue

        ############# VALID #############
        val_loss = 0.0
        val_lwlrap = 0.0
        x_preds = np.array([])
        y_preds = np.array([])
        val_preds_frame = []
        n_iter_val = len(validloader)
#         for i, (bssid, rssi, site_id) in tqdm(enumerate(validloader), total=len(validloader)):
        for i, (bssid, rssi, site_id) in enumerate(progress_bar(validloader, parent=mb)):
            mb.child.comment = 'calc valid'
            net.eval()

            with torch.no_grad():
                
                #melspec, labels = melspec.to(device).float(), labels.to(device).float()
                bssid, rssi, site_id = bssid.to(device).long(), rssi.to(device).float(), site_id.to(device).long()
                xy_pred, floor_pred = net(bssid, rssi, site_id)

                xy_pred = xy_pred.to('cpu').detach().numpy().copy()
                x_pred, y_pred = np.hsplit(xy_pred, 2)
                x_preds = np.concatenate([x_preds, x_pred.reshape(-1)])
                y_preds = np.concatenate([y_preds, y_pred.reshape(-1)])

        score = comp_metric(x_preds, y_preds, 0, valid['x'], valid['y'], 0)

        early_stopping(score, net)

        if early_stopping.early_stop:
            logger.info("Early stopping")
            cv_scores[f'cv{fold + 1}'] = early_stopping.best_score
            break
                
    _x_oof = np.array([])
    _y_oof = np.array([])
    ############# OOF #############
    oof_preds = []
#     for i, (bssid, rssi, site_id) in tqdm(enumerate(validloader), total=len(validloader)):
    for i, (bssid, rssi, site_id) in enumerate(progress_bar(validloader, parent=mb)):
#         net.load_state_dict(torch.load(ROOT_DIR / Path('output') / f'checkpoint_{NB}_{fold}.pt'))
        net.load_state_dict(torch.load(f'{DIR_SAVE_IGNORE}checkpoint_{NB}_{fold + 1}.pt'))
        net.eval()

        with torch.no_grad():

            bssid, rssi, site_id, x, y, floor = bssid.to(device).long(), rssi.to(device).float(), site_id.to(device).long(), x.to(device).float(), y.to(device).float(), floor.to(device)

            xy_pred, floor_pred = net(bssid, rssi, site_id)

            xy_pred = xy_pred.to('cpu').detach().numpy().copy()
            x_pred, y_pred = np.hsplit(xy_pred, 2)
            _x_oof = np.concatenate([_x_oof, x_pred.reshape(-1)])
            _y_oof = np.concatenate([_y_oof, y_pred.reshape(-1)])

    print(comp_metric(_x_oof, _y_oof, 0, valid['x'], valid['y'], 0))

    oof_x[valid_index] = _x_oof
    oof_y[valid_index] = _y_oof

    del net
    torch.cuda.empty_cache()
# Out:
# ====== 1 ======
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00
| INFO     | __main__:save_checkpoint:46 - Validation loss decreased (60.827351 --> 60.527310).  Saving model ...
# 2021-04-09 12:35:00.954 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (60.527310 --> 59.048749).  Saving model ...
# 2021-04-09 12:35:01.431 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (59.048749 --> 57.705206).  Saving model ...
# 2021-04-09 12:35:01.898 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (57.705206 --> 54.870898).  Saving model ...
# 2021-04-09 12:35:02.365 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (54.870898 --> 51.847787).  Saving model ...
# 2021-04-09 12:35:02.834 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (51.847787 --> 47.522622).  Saving model ...
# 2021-04-09 12:35:03.295 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (47.522622 --> 41.050755).  Saving model ...
# 2021-04-09 12:35:03.761 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (41.050755 --> 40.854156).  Saving model ...
# 2021-04-09 12:35:04.221 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (40.854156 --> 37.033091).  Saving model ...
# 2021-04-09 12:35:04.684 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (37.033091 --> 32.987111).  Saving model ...
# 2021-04-09 12:35:05.153 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (32.987111 --> 29.498712).  Saving model ...
# 2021-04-09 12:35:05.624 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (29.498712 --> 27.060606).  Saving model ...
# 2021-04-09 12:35:06.092 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (27.060606 --> 25.696821).  Saving model ...
# 2021-04-09 12:35:06.553 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (25.696821 --> 23.603400).  Saving model ...
# 2021-04-09 12:35:07.015 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (23.603400 --> 22.609380).  Saving model ...
# 2021-04-09 12:35:07.481 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (22.609380 --> 21.976543).  Saving model ...
# 2021-04-09 12:35:07.950 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (21.976543 --> 21.765251).  Saving model ...
# 2021-04-09 12:35:08.416 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (21.765251 --> 21.029871).  Saving model ...
# 2021-04-09 12:35:08.871 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (21.029871 --> 20.987003).  Saving model ...
# 2021-04-09 12:35:09.334 | INFO     | __main__:__call__:35 - EarlyStopping counter: 1 out of 10
# 2021-04-09 12:35:09.796 | INFO     | __main__:__call__:35 - EarlyStopping counter: 2 out of 10
# 2021-04-09 12:35:10.261 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (20.987003 --> 20.260828).  Saving model ...
# 2021-04-09 12:35:10.743 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (20.260828 --> 19.826143).  Saving model ...
# 2021-04-09 12:35:11.207 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (19.826143 --> 19.308167).  Saving model ...
# 2021-04-09 12:35:11.684 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (19.308167 --> 17.263691).  Saving model ...
# 2021-04-09 12:35:12.145 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (17.263691 --> 15.416018).  Saving model ...
# 2021-04-09 12:35:12.615 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (15.416018 --> 15.346316).  Saving model ...
# 2021-04-09 12:35:13.088 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (15.346316 --> 13.190885).  Saving model ...
# 13.190884952040157
#
# ====== 2 ======
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:52<00:00 epoch = 100]
#     </div>
#
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4/4 00:00<00:00]
#     </div>
# 2021-04-09 12:35:13.857 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (inf --> 246.392471).  Saving model ...
# 2021-04-09 12:35:14.355 | INFO     | __main__:__call__:35 - EarlyStopping counter: 1 out of 10
# 2021-04-09 12:35:14.851 | INFO     | __main__:__call__:35 - EarlyStopping counter: 2 out of 10
# 2021-04-09 12:35:15.361 | INFO     | __main__:__call__:35 - EarlyStopping counter: 3 out of 10
# 2021-04-09 12:35:15.862 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (246.392471 --> 246.343898).  Saving model ...
# 2021-04-09 12:35:16.371 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (246.343898 --> 245.236064).  Saving model ...
# 2021-04-09 12:35:16.884 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (245.236064 --> 244.452415).  Saving model ...
# 2021-04-09 12:35:17.411 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased
| INFO     | __main__:save_checkpoint:46 - Validation loss decreased (19.340501 --> 17.529729).  Saving model ...
# 2021-04-09 12:37:43.649 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (17.529729 --> 15.808253).  Saving model ...
# 2021-04-09 12:37:44.127 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (15.808253 --> 15.076590).  Saving model ...
# 2021-04-09 12:37:44.608 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (15.076590 --> 14.737290).  Saving model ...
# 14.737289794192066
#
# ====== 5 ======
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:57<00:00 epoch = 100]
#     </div>
#
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4/4 00:00<00:00]
#     </div>
# 2021-04-09 12:37:45.389 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (inf --> 248.889386).  Saving model ...
# 2021-04-09 12:37:45.884 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (248.889386 --> 247.987207).  Saving model ...
# 2021-04-09 12:37:46.372 | INFO     | __main__:__call__:35 - EarlyStopping counter: 1 out of 10
# 2021-04-09 12:37:46.871 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (247.987207 --> 247.397197).  Saving model ...
# 2021-04-09 12:37:47.393 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (247.397197 --> 246.294626).  Saving model ...
# 2021-04-09 12:37:47.885 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (246.294626 --> 245.768341).  Saving model ...
# 2021-04-09 12:37:48.385 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (245.768341 --> 245.535593).  Saving model ...
# 2021-04-09 12:37:48.936 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (245.535593 --> 244.939456).  Saving model ...
# 2021-04-09 12:37:49.502 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (244.939456 --> 244.865653).  Saving model ...
# 2021-04-09 12:37:50.068 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (244.865653 --> 244.716759).  Saving model ...
# 2021-04-09 12:37:50.643 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (244.716759 --> 244.636945).  Saving model ...
# 2021-04-09 12:37:51.183 | INFO     | __main__:__call__:35 - EarlyStopping counter: 1 out of 10
# 2021-04-09 12:37:51.724 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (244.636945 --> 244.096089).  Saving model ...
# 2021-04-09 12:37:52.297 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (244.096089 --> 243.434308).  Saving model ...
# 2021-04-09 12:37:52.860 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (243.434308 --> 242.324275).  Saving model ...
# 2021-04-09 12:37:53.408 | INFO     | __main__:__call__:35 - EarlyStopping counter: 1 out of 10
# 2021-04-09 12:37:53.963 | INFO     | __main__:__call__:35 - EarlyStopping counter: 2 out of 10
# 2021-04-09 12:37:54.515 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (242.324275 --> 237.496705).  Saving model ...
# 2021-04-09 12:37:55.095 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (237.496705 --> 233.757076).  Saving model ...
# 2021-04-09 12:37:55.645 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (233.757076 --> 229.986389).  Saving model ...
# 2021-04-09 12:37:56.216 | INFO     | __main__:__call__:35 - EarlyStopping counter: 1 out of 10
# 2021-04-09 12:37:56.792 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (229.986389 --> 220.567311).  Saving model ...
# 2021-04-09 12:37:57.374 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (220.567311 --> 216.605994).  Saving model ...
# 2021-04-09 12:37:57.919 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (216.605994 --> 213.075567).  Saving model ...
# 2021-04-09 12:37:58.493 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (213.075567 --> 204.905061).  Saving model ...
# 2021-04-09 12:37:59.041 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (204.905061 --> 201.152780).  Saving model ...
# 2021-04-09 12:37:59.570 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (201.152780 --> 198.582213).  Saving model ...
# 2021-04-09 12:38:00.121 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (198.582213 --> 197.806470).  Saving model ...
# 2021-04-09 12:38:00.699 | INFO     | __main__:__call__:35 - EarlyStopping counter: 1 out of 10
# 2021-04-09 12:38:01.251 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (197.806470 --> 197.660150).  Saving model ...
# 2021-04-09 12:38:01.811 | INFO     | __main__:__call__:35 - EarlyStopping counter: 1 out of 10
# 2021-04-09 12:38:02.377 | INFO     | __main__:__call__:35 - EarlyStopping counter: 2 out of 10
# 2021-04-09 12:38:02.912 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (197.660150 --> 196.790833).  Saving model ...
# 2021-04-09 12:38:03.492 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (196.790833 --> 195.632699).  Saving model ...
# 2021-04-09 12:38:04.052 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (195.632699 --> 192.908532).  Saving model ...
# 2021-04-09 12:38:04.628 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (192.908532 --> 188.534969).  Saving model ...
# 2021-04-09 12:38:05.206 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (188.534969 --> 184.753224).  Saving model ...
# 2021-04-09 12:38:05.768 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (184.753224 --> 180.413957).  Saving model ...
# 2021-04-09 12:38:06.340 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (180.413957 --> 173.205676).  Saving model ...
# 2021-04-09 12:38:06.898 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (173.205676 --> 163.365849).  Saving model ...
# 2021-04-09 12:38:07.468 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (163.365849 --> 155.002765).  Saving model ...
# 2021-04-09 12:38:08.050 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (155.002765 --> 150.204824).  Saving model ...
# 2021-04-09 12:38:08.623 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (150.204824 --> 142.977836).  Saving model ...
# 2021-04-09 12:38:09.203 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (142.977836 --> 137.145240).  Saving model ...
# 2021-04-09 12:38:09.766 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (137.145240 --> 130.752083).  Saving model ...
# 2021-04-09 12:38:10.375 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (130.752083 --> 127.719657).  Saving model ...
# 2021-04-09 12:38:10.955 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (127.719657 --> 126.298031).  Saving model ...
# 2021-04-09 12:38:11.536 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (126.298031 --> 125.392994).  Saving model ...
# 2021-04-09 12:38:12.122 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (125.392994 --> 124.377551).  Saving model ...
# 2021-04-09 12:38:12.745 | INFO     | __main__:__call__:35 - EarlyStopping counter: 1 out of 10
# 2021-04-09 12:38:13.339 | INFO     | __main__:__call__:35 - EarlyStopping counter: 2 out of 10
# 2021-04-09 12:38:13.909 | INFO     | __main__:__call__:35 - EarlyStopping counter: 3 out of 10
# 2021-04-09 12:38:14.521 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (124.377551 --> 123.732839).  Saving model ...
# 2021-04-09 12:38:15.122 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (123.732839 --> 122.152868).  Saving model ...
# 2021-04-09 12:38:15.740 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (122.152868 --> 120.050957).  Saving model ...
# 2021-04-09 12:38:16.337 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (120.050957 --> 116.396856).  Saving model ...
# 2021-04-09 12:38:16.921 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (116.396856 --> 110.699303).  Saving model ...
# 2021-04-09 12:38:17.543 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (110.699303 --> 106.144049).  Saving model ...
# 2021-04-09 12:38:18.119 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (106.144049 --> 98.749316).  Saving model ...
# 2021-04-09 12:38:18.714 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (98.749316 --> 92.696217).  Saving model ...
# 2021-04-09 12:38:19.303 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (92.696217 --> 84.374351).  Saving model ...
# 2021-04-09 12:38:19.930 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (84.374351 --> 79.013486).  Saving model ...
# 2021-04-09 12:38:20.512 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (79.013486 --> 73.727790).  Saving model ...
# 2021-04-09 12:38:21.099 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (73.727790 --> 69.274614).  Saving model ...
# 2021-04-09 12:38:21.716 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (69.274614 --> 64.196304).  Saving model ...
# 2021-04-09 12:38:22.346 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (64.196304 --> 63.631890).  Saving model ...
# 2021-04-09 12:38:22.975 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (63.631890 --> 62.060000).  Saving model ...
# 2021-04-09 12:38:23.601 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (62.060000 --> 61.050346).  Saving model ...
# 2021-04-09 12:38:24.229 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (61.050346 --> 60.783981).  Saving model ...
# 2021-04-09 12:38:24.846 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (60.783981 --> 60.749785).  Saving model ...
# 2021-04-09 12:38:25.436 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (60.749785 --> 60.703738).  Saving model ...
# 2021-04-09 12:38:26.025 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (60.703738 --> 60.631453).  Saving model ...
# 2021-04-09 12:38:26.618 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (60.631453 --> 60.166700).  Saving model ...
# 2021-04-09 12:38:27.203 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (60.166700 --> 59.242435).  Saving model ...
# 2021-04-09 12:38:27.794 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (59.242435 --> 57.355016).  Saving model ...
# 2021-04-09 12:38:28.380 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (57.355016 --> 53.628263).  Saving model ...
# 2021-04-09 12:38:28.964 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (53.628263 --> 50.878780).  Saving model ...
# 2021-04-09 12:38:29.557 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (50.878780 --> 47.002233).  Saving model ...
# 2021-04-09 12:38:30.132 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (47.002233 --> 43.166607).  Saving model ...
# 2021-04-09 12:38:30.720 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (43.166607 --> 38.731943).  Saving model ...
# 2021-04-09 12:38:31.317 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (38.731943 --> 35.981376).  Saving model ...
# 2021-04-09 12:38:31.912 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (35.981376 --> 31.101244).  Saving model ...
# 2021-04-09 12:38:32.509 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (31.101244 --> 26.891705).  Saving model ...
# 2021-04-09 12:38:33.099 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (26.891705 --> 24.774823).  Saving model ...
# 2021-04-09 12:38:33.696 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (24.774823 --> 24.754195).  Saving model ...
# 2021-04-09 12:38:34.274 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (24.754195 --> 23.432189).  Saving model ...
# 2021-04-09 12:38:34.857 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (23.432189 --> 22.927094).  Saving model ...
# 2021-04-09 12:38:35.452 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (22.927094 --> 21.778436).  Saving model ...
# 2021-04-09 12:38:36.041 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (21.778436 --> 21.657644).  Saving model ...
# 2021-04-09 12:38:36.629 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (21.657644 --> 21.349520).  Saving model ...
# 2021-04-09 12:38:37.240 | INFO     | __main__:__call__:35 - EarlyStopping counter: 1 out of 10
# 2021-04-09 12:38:37.835 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (21.349520 --> 20.810766).  Saving model ...
# 2021-04-09 12:38:38.424 | INFO     | __main__:__call__:35 - EarlyStopping counter: 1 out of 10
# 2021-04-09 12:38:39.013 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (20.810766 --> 20.740064).  Saving model ...
# 2021-04-09 12:38:39.603 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (20.740064 --> 19.690244).  Saving model ...
# 2021-04-09 12:38:40.202 | INFO     | __main__:__call__:35 - EarlyStopping counter: 1 out of 10
# 2021-04-09 12:38:40.776 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (19.690244 --> 17.173396).  Saving model ...
# 2021-04-09 12:38:41.352 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (17.173396 --> 15.871792).  Saving model ...
# 2021-04-09 12:38:41.939 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (15.871792 --> 14.528106).  Saving model ...
# 2021-04-09 12:38:42.536 | INFO     | __main__:save_checkpoint:46 - Validation loss decreased (14.528106 --> 14.008922).  Saving model ...
# 14.008922163016356
# CPU times: user 1min 4s, sys: 2min 5s, total: 3min 9s
# Wall time: 4min 18s

# %%
oof_score = comp_metric(oof_x, oof_y, np.zeros(len(df_train)), df_train['x'], df_train['y'], np.zeros(len(df_train)))
oof_score
# Out:
# 13.451590608358291
